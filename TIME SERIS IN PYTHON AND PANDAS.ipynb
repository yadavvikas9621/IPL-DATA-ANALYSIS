# %%
import pandas as pd
import datetime as dt
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('C:\\Users\\VIKAS\\Documents\\ipldata (1)\\HistoricalQuotes.csv',parse_dates=['date'],index_col='date')
df
# Out:
#                       close      volume     open      high       low
# date
# 2019-07-02 16:00:00  197.92  31,075,847  198.610  199.4950  197.0500
# 2019-06-28 00:00:00  197.92    31110640  198.680  199.4950  197.0500
# 2019-06-27 00:00:00  199.74    20899720  200.290  201.5700  199.5700
# 2019-06-26 00:00:00  199.80    26067510  197.770  200.9900  197.3500
# 2019-06-25 00:00:00  195.57    21070330  198.430  199.2600  195.2900
# 2019-06-24 00:00:00  198.58    18220420  198.540  200.1600  198.1700
# 2019-06-21 00:00:00  198.78    47800590  198.800  200.8500  198.1500
# 2019-06-20 00:00:00  199.46    21513990  200.370  200.6100  198.0300
# 2019-06-19 00:00:00  197.87    21124240  199.680  199.8800  197.3100
# 2019-06-18 00:00:00  198.45    26551000  196.050  200.2900  195.2100
# 2019-06-17 00:00:00  193.89    14669140  192.900  194.9600  192.1700
# 2019-06-14 00:00:00  192.74    18761470  191.545  193.5863  190.3000
# ...

# %%
df.index
# Out:
# DatetimeIndex(['2019-07-01 16:00:00', '2019-06-28 00:00:00',
#                '2019-06-27 00:00:00', '2019-06-26 00:00:00',
#                '2019-06-25 00:00:00', '2019-06-24 00:00:00',
#                '2019-06-21 00:00:00', '2019-06-20 00:00:00',
#                '2019-06-19 00:00:00', '2019-06-18 00:00:00',
#                '2019-06-17 00:00:00', '2019-06-14 00:00:00',
#                '2019-06-13 00:00:00', '2019-06-12 00:00:00',
#                '2019-06-11 00:00:00', '2019-06-10 00:00:00',
#                '2019-06-07 00:00:00', '2019-06-06 00:00:00',
#                '2019-06-05 00:00:00', '2019-06-04 00:00:00',
#                '2019-06-03 00:00:00', '2019-05-31 00:00:00',
#                '2019-05-30 00:00:00', '2019-05-29 00:00:00',
#                '2019-05-28 00:00:00', '2019-05-24 00:00:00',
#                '2019-05-23 00:00:00', '2019-05-22 00:00:00',
#                '2019-05-21 00:00:00', '2019-05-20 00:00:00',
# ...

# %%
df['2019-07-01':'2019-04-04']
# Out:
#              close    volume     open      high       low
# date
# 2019-06-28  197.92  31110640  198.680  199.4950  197.0500
# 2019-06-27  199.74  20899720  200.290  201.5700  199.5700
# 2019-06-26  199.80  26067510  197.770  200.9900  197.3500
# 2019-06-25  195.57  21070330  198.430  199.2600  195.2900
# 2019-06-24  198.58  18220420  198.540  200.1600  198.1700
# 2019-06-21  198.78  47800590  198.800  200.8500  198.1500
# 2019-06-20  199.46  21513990  200.370  200.6100  198.0300
# 2019-06-19  197.87  21124240  199.680  199.8800  197.3100
# 2019-06-18  198.45  26551000  196.050  200.2900  195.2100
# 2019-06-17  193.89  14669140  192.900  194.9600  192.1700
# 2019-06-14  192.74  18761470  191.545  193.5863  190.3000
# 2019-06-13  194.15  21674630  194.700  196.7900  193.6000
# 2019-06-12  194.19  18253190  193.950  195.9700  193.3850
# 2019-06-11  194.81  26932880  194.860  196.0000  193.6000
# 2019-06-10  192.58  26220850  191.810  195.3700  191.6200
# ...

# %%
df.close.resample('M').mean().plot(kind='bar')

# %%
df.close.resample('M').mean().plot(kind='pie')

# %%
df.close.resample('M').mean().plot(kind='hist')

# %%
df.close.resample('M').mean().plot()

# %%
df.close.plot()

# %%
df=pd.read_csv('C:\\Users\\VIKAS\\Documents\\ipldata (1)\\Apple.csv')           #COLLECTE THE DATA AND ANALYSIS #
df
# Out:
#      close      volume     open      high       low
# 0   197.92  31,075,847  198.610  199.4950  197.0500
# 1   197.92    31110640  198.680  199.4950  197.0500
# 2   199.74    20899720  200.290  201.5700  199.5700
# 3   199.80    26067510  197.770  200.9900  197.3500
# 4   195.57    21070330  198.430  199.2600  195.2900
# 5   198.58    18220420  198.540  200.1600  198.1700
# 6   198.78    47800590  198.800  200.8500  198.1500
# 7   199.46    21513990  200.370  200.6100  198.0300
# 8   197.87    21124240  199.680  199.8800  197.3100
# 9   198.45    26551000  196.050  200.2900  195.2100
# 10  193.89    14669140  192.900  194.9600  192.1700
# 11  192.74    18761470  191.545  193.5863  190.3000
# 12  194.15    21674630  194.700  196.7900  193.6000
# 13  194.19    18253190  193.950  195.9700  193.3850
# 14  194.81    26932880  194.860  196.0000  193.6000
# 15  192.58    26220850  191.810  195.3700  191.6200
# 16  190.15    30684390  186.510  191.9200  185.7700
# ...

# %%
rng=pd.date_range(start='1/1/2018', end='3/6/2018')#ADD DATE IN RABGE#
rng
# Out:
# DatetimeIndex(['2018-01-01', '2018-01-02', '2018-01-03', '2018-01-04',
#                '2018-01-05', '2018-01-06', '2018-01-07', '2018-01-08',
#                '2018-01-09', '2018-01-10', '2018-01-11', '2018-01-12',
#                '2018-01-13', '2018-01-14', '2018-01-15', '2018-01-16',
#                '2018-01-17', '2018-01-18', '2018-01-19', '2018-01-20',
#                '2018-01-21', '2018-01-22', '2018-01-23', '2018-01-24',
#                '2018-01-25', '2018-01-26', '2018-01-27', '2018-01-28',
#                '2018-01-29', '2018-01-30', '2018-01-31', '2018-02-01',
#                '2018-02-02', '2018-02-03', '2018-02-04', '2018-02-05',
#                '2018-02-06', '2018-02-07', '2018-02-08', '2018-02-09',
#                '2018-02-10', '2018-02-11', '2018-02-12', '2018-02-13',
#                '2018-02-14', '2018-02-15', '2018-02-16', '2018-02-17',
#                '2018-02-18', '2018-02-19', '2018-02-20', '2018-02-21',
# ...

# %%
df.set_index(rng,inplace=True)#ADD DATE IN INDEX #

# %%
df
# Out:
#              close      volume     open      high       low
# 2018-01-01  197.92  31,075,847  198.610  199.4950  197.0500
# 2018-01-02  197.92    31110640  198.680  199.4950  197.0500
# 2018-01-03  199.74    20899720  200.290  201.5700  199.5700
# 2018-01-04  199.80    26067510  197.770  200.9900  197.3500
# 2018-01-05  195.57    21070330  198.430  199.2600  195.2900
# 2018-01-06  198.58    18220420  198.540  200.1600  198.1700
# 2018-01-07  198.78    47800590  198.800  200.8500  198.1500
# 2018-01-08  199.46    21513990  200.370  200.6100  198.0300
# 2018-01-09  197.87    21124240  199.680  199.8800  197.3100
# 2018-01-10  198.45    26551000  196.050  200.2900  195.2100
# 2018-01-11  193.89    14669140  192.900  194.9600  192.1700
# 2018-01-12  192.74    18761470  191.545  193.5863  190.3000
# 2018-01-13  194.15    21674630  194.700  196.7900  193.6000
# 2018-01-14  194.19    18253190  193.950  195.9700  193.3850
# 2018-01-15  194.81    26932880  194.860  196.0000  193.6000
# ...

# %%
df.close.plot()

# %%
df['2018-01-01':'2018-01-10'].close.mean()
# Out:
# 198.409

# %%
df.asfreq('D',method='pad')
# Out:
#              close      volume     open      high       low
# 2018-01-01  197.92  31,075,847  198.610  199.4950  197.0500
# 2018-01-02  197.92    31110640  198.680  199.4950  197.0500
# 2018-01-03  199.74    20899720  200.290  201.5700  199.5700
# 2018-01-04  199.80    26067510  197.770  200.9900  197.3500
# 2018-01-05  195.57    21070330  198.430  199.2600  195.2900
# 2018-01-06  198.58    18220420  198.540  200.1600  198.1700
# 2018-01-07  198.78    47800590  198.800  200.8500  198.1500
# 2018-01-08  199.46    21513990  200.370  200.6100  198.0300
# 2018-01-09  197.87    21124240  199.680  199.8800  197.3100
# 2018-01-10  198.45    26551000  196.050  200.2900  195.2100
# 2018-01-11  193.89    14669140  192.900  194.9600  192.1700
# 2018-01-12  192.74    18761470  191.545  193.5863  190.3000
# 2018-01-13  194.15    21674630  194.700  196.7900  193.6000
# 2018-01-14  194.19    18253190  193.950  195.9700  193.3850
# 2018-01-15  194.81    26932880  194.860  196.0000  193.6000
# ...

# %%
df.asfreq('W',method='pad')
# Out:
#              close    volume    open    high       low
# 2018-01-07  198.78  47800590  198.80  200.85  198.1500
# 2018-01-14  194.19  18253190  193.95  195.97  193.3850
# 2018-01-21  173.30  40396070  175.60  177.92  170.2700
# 2018-01-28  182.78  29748560  184.66  185.71  182.5500
# 2018-02-04  185.72  57430620  187.71  189.48  182.8500
# 2018-02-11  209.15  31996320  209.84  212.65  208.1300
# 2018-02-18  207.48  23286380  204.43  207.75  203.9000
# 2018-02-25  198.95  20543190  200.85  201.00  198.4431
# 2018-03-04  194.02  22727370  191.09  194.46  191.0500

# %%
df.asfreq('H',method='pad').
# Out:
#                       close      volume    open     high     low
# 2018-01-01 00:00:00  197.92  31,075,847  198.61  199.495  197.05
# 2018-01-01 01:00:00  197.92  31,075,847  198.61  199.495  197.05
# 2018-01-01 02:00:00  197.92  31,075,847  198.61  199.495  197.05
# 2018-01-01 03:00:00  197.92  31,075,847  198.61  199.495  197.05
# 2018-01-01 04:00:00  197.92  31,075,847  198.61  199.495  197.05
# 2018-01-01 05:00:00  197.92  31,075,847  198.61  199.495  197.05
# 2018-01-01 06:00:00  197.92  31,075,847  198.61  199.495  197.05
# 2018-01-01 07:00:00  197.92  31,075,847  198.61  199.495  197.05
# 2018-01-01 08:00:00  197.92  31,075,847  198.61  199.495  197.05
# 2018-01-01 09:00:00  197.92  31,075,847  198.61  199.495  197.05
# 2018-01-01 10:00:00  197.92  31,075,847  198.61  199.495  197.05
# 2018-01-01 11:00:00  197.92  31,075,847  198.61  199.495  197.05
# 2018-01-01 12:00:00  197.92  31,075,847  198.61  199.495  197.05
# ...

# %%
RNG=pd.date_range(start="1/01/2018",periods=72,freq='B')
RNG
# Out:
# DatetimeIndex(['2018-01-01', '2018-01-02', '2018-01-03', '2018-01-04',
#                '2018-01-05', '2018-01-08', '2018-01-09', '2018-01-10',
#                '2018-01-11', '2018-01-12', '2018-01-15', '2018-01-16',
#                '2018-01-17', '2018-01-18', '2018-01-19', '2018-01-22',
#                '2018-01-23', '2018-01-24', '2018-01-25', '2018-01-26',
#                '2018-01-29', '2018-01-30', '2018-01-31', '2018-02-01',
#                '2018-02-02', '2018-02-05', '2018-02-06', '2018-02-07',
#                '2018-02-08', '2018-02-09', '2018-02-12', '2018-02-13',
#                '2018-02-14', '2018-02-15', '2018-02-16', '2018-02-19',
#                '2018-02-20', '2018-02-21', '2018-02-22', '2018-02-23',
#                '2018-02-26', '2018-02-27', '2018-02-28', '2018-03-01',
#                '2018-03-02', '2018-03-05', '2018-03-06', '2018-03-07',
#                '2018-03-08', '2018-03-09', '2018-03-12', '2018-03-13',
# ...

# %%
ts=pd.Series(np.random.randint(1,10,len(RNG)),index=RNG)
ts
# Out:
# 2018-01-01    8
# 2018-01-02    1
# 2018-01-03    4
# 2018-01-04    6
# 2018-01-05    5
# 2018-01-08    3
# 2018-01-09    4
# 2018-01-10    7
# 2018-01-11    6
# 2018-01-12    9
# 2018-01-15    6
# 2018-01-16    5
# 2018-01-17    2
# 2018-01-18    4
# 2018-01-19    7
# 2018-01-22    4
# 2018-01-23    4
# 2018-01-24    9
# 2018-01-25    4
# 2018-01-26    9
# 2018-01-29    5
# 2018-01-30    6
# 2018-01-31    2
# 2018-02-01    9
# 2018-02-02    9
# 2018-02-05    3
# 2018-02-06    4
# 2018-02-07    6
# 2018-02-08    7
# 2018-02-09    8
#              ..
# 2018-02-28    9
# 2018-03-01    3
# 2018-03-02    5
# 2018-03-05    8
# 2018-03-06    3
# 2018-03-07    3
# 2018-03-08    6
# 2018-03-09    7
# 2018-03-12    3
# 2018-03-13    3
# 2018-03-14    7
# 2018-03-15    7
# 2018-03-16    3
# 2018-03-19    8
# 2018-03-20    8
# 2018-03-21    1
# 2018-03-22    7
# 2018-03-23    4
# 2018-03-26    4
# 2018-03-27    4
# 2018-03-28    6
# 2018-03-29    3
# 2018-03-30    7
# 2018-04-02    6
# ...

# %%
#how to hundell the holiydays and provide custome date#
DF=pd.read_csv('C:\\Users\\VIKAS\\Documents\\ipldata (1)\\Apple.csv')           #COLLECTE THE DATA AND ANALYSIS #
DF
# Out:
#      close      volume     open      high       low
# 0   197.92  31,075,847  198.610  199.4950  197.0500
# 1   197.92    31110640  198.680  199.4950  197.0500
# 2   199.74    20899720  200.290  201.5700  199.5700
# 3   199.80    26067510  197.770  200.9900  197.3500
# 4   195.57    21070330  198.430  199.2600  195.2900
# 5   198.58    18220420  198.540  200.1600  198.1700
# 6   198.78    47800590  198.800  200.8500  198.1500
# 7   199.46    21513990  200.370  200.6100  198.0300
# 8   197.87    21124240  199.680  199.8800  197.3100
# 9   198.45    26551000  196.050  200.2900  195.2100
# 10  193.89    14669140  192.900  194.9600  192.1700
# 11  192.74    18761470  191.545  193.5863  190.3000
# 12  194.15    21674630  194.700  196.7900  193.6000
# 13  194.19    18253190  193.950  195.9700  193.3850
# 14  194.81    26932880  194.860  196.0000  193.6000
# 15  192.58    26220850  191.810  195.3700  191.6200
# 16  190.15    30684390  186.510  191.9200  185.7700
# ...

# %%
A=DF.head(14)
A
# Out:
#      close      volume     open      high      low
# 0   197.92  31,075,847  198.610  199.4950  197.050
# 1   197.92    31110640  198.680  199.4950  197.050
# 2   199.74    20899720  200.290  201.5700  199.570
# 3   199.80    26067510  197.770  200.9900  197.350
# 4   195.57    21070330  198.430  199.2600  195.290
# 5   198.58    18220420  198.540  200.1600  198.170
# 6   198.78    47800590  198.800  200.8500  198.150
# 7   199.46    21513990  200.370  200.6100  198.030
# 8   197.87    21124240  199.680  199.8800  197.310
# 9   198.45    26551000  196.050  200.2900  195.210
# 10  193.89    14669140  192.900  194.9600  192.170
# 11  192.74    18761470  191.545  193.5863  190.300
# 12  194.15    21674630  194.700  196.7900  193.600
# 13  194.19    18253190  193.950  195.9700  193.385

# %% [markdown]
# pd.date_range(satrt="1/1/2018",end="1/21/2018,freq="B")

# %%
pd.date_range(start="7/1/2017",end="7/21/2017",freq="B")#finde the hoolydays in Us#
# Out:
# DatetimeIndex(['2017-07-03', '2017-07-04', '2017-07-05', '2017-07-06',
#                '2017-07-07', '2017-07-10', '2017-07-11', '2017-07-12',
#                '2017-07-13', '2017-07-14', '2017-07-17', '2017-07-18',
#                '2017-07-19', '2017-07-20', '2017-07-21'],
#               dtype='datetime64[ns]', freq='B')

# %%
from pandas.tseries.holiday import USFederalHolidayCalendar
from pandas.tseries.offsets import CustomBusinessDay
call = CustomBusinessDay(calendar=USFederalHolidayCalendar())
call

# %%
noholida =pd.date_range(start="7/1/2017",end="7/21/2017",freq=call)
noholida
# Out:
# DatetimeIndex(['2017-07-03', '2017-07-05', '2017-07-06', '2017-07-07',
#                '2017-07-10', '2017-07-11', '2017-07-12', '2017-07-13',
#                '2017-07-14', '2017-07-17', '2017-07-18', '2017-07-19',
#                '2017-07-20', '2017-07-21'],
#               dtype='datetime64[ns]', freq='C')

# %%
A.set_index(noholida,inplace=True)
A
# Out:
#              close      volume     open      high      low
# 2017-07-03  197.92  31,075,847  198.610  199.4950  197.050
# 2017-07-05  197.92    31110640  198.680  199.4950  197.050
# 2017-07-06  199.74    20899720  200.290  201.5700  199.570
# 2017-07-07  199.80    26067510  197.770  200.9900  197.350
# 2017-07-10  195.57    21070330  198.430  199.2600  195.290
# 2017-07-11  198.58    18220420  198.540  200.1600  198.170
# 2017-07-12  198.78    47800590  198.800  200.8500  198.150
# 2017-07-13  199.46    21513990  200.370  200.6100  198.030
# 2017-07-14  197.87    21124240  199.680  199.8800  197.310
# 2017-07-17  198.45    26551000  196.050  200.2900  195.210
# 2017-07-18  193.89    14669140  192.900  194.9600  192.170
# 2017-07-19  192.74    18761470  191.545  193.5863  190.300
# 2017-07-20  194.15    21674630  194.700  196.7900  193.600
# 2017-07-21  194.19    18253190  193.950  195.9700  193.385

# %%
A.plot()

# %%
A.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0D0E0D30>,
# ...
#       dtype=object)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
d=pd.read_csv('C:\\Users\\VIKAS\\Documents\\ipldata (1)\\deliveries.csv')#import a csv file for ipl data from computer#
d
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 0              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 5              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 6              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 7              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 8              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 9              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 10             1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...

# %%
d.head() #Show on starting 5 records in data set
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  noball_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...            0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...            0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...            0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...            0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...            0
#
# ...

# %%
d.tail()#show on last 5 record in data set
# Out:
#         match_id  inning         batting_team         bowling_team  over  \
# 164745      7953       2  Chennai Super Kings  Sunrisers Hyderabad    18
# 164746      7953       2  Chennai Super Kings  Sunrisers Hyderabad    18
# 164747      7953       2  Chennai Super Kings  Sunrisers Hyderabad    19
# 164748      7953       2  Chennai Super Kings  Sunrisers Hyderabad    19
# 164749      7953       2  Chennai Super Kings  Sunrisers Hyderabad    19
#
#         ball    batsman non_striker         bowler  is_super_over  ...  \
# 164745     5  SR Watson   AT Rayudu         S Kaul              0  ...
# 164746     6  SR Watson   AT Rayudu         S Kaul              0  ...
# 164747     1  AT Rayudu   SR Watson  CR Brathwaite              0  ...
# 164748     2  AT Rayudu   SR Watson  CR Brathwaite              0  ...
# 164749     3  AT Rayudu   SR Watson  CR Brathwaite              0  ...
#
#         noball_runs  penalty_runs  batsman_runs  extra_runs  total_runs  \
# ...

# %%
d.describe()
# Out:
#             match_id         inning           over           ball  \
# count  164750.000000  164750.000000  164750.000000  164750.000000
# mean      977.951757       1.482307      10.151879       3.616243
# std      2147.671843       0.501592       5.675666       1.807398
# min         1.000000       1.000000       1.000000       1.000000
# 25%       175.000000       1.000000       5.000000       2.000000
# 50%       349.000000       1.000000      10.000000       4.000000
# 75%       521.000000       2.000000      15.000000       5.000000
# max      7953.000000       4.000000      20.000000       9.000000
#
#        is_super_over      wide_runs       bye_runs    legbye_runs  \
# count  164750.000000  164750.000000  164750.000000  164750.000000
# mean        0.000492       0.037184       0.004898       0.021548
# std         0.022168       0.254087       0.115006       0.196410
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
r.median()
# Out:
# C:\Users\VIKAS\AppData\Local\Programs\Python\Python37-32\lib\site-packages\numpy\lib\nanfunctions.py:1076: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# match_id         349.0
# inning             1.0
# over              10.0
# ball               4.0
# is_super_over      0.0
# wide_runs          0.0
# bye_runs           0.0
# legbye_runs        0.0
# noball_runs        0.0
# penalty_runs       0.0
# batsman_runs       1.0
# extra_runs         0.0
# total_runs         1.0
# Unnamed: 21        NaN
# dtype: float64

# %%
#find the one batman run in ipl match#
batsman_grp = d.groupby([ "batsman"])
batsmen = batsman_grp["batsman_runs"].sum()
batsmen
# Out:
# batsman
# A Ashish Reddy           280
# A Chandila                 4
# A Chopra                  53
# A Choudhary               25
# A Dananjaya                4
# A Flintoff                62
# A Hales                  152
# A Kumble                  35
# A Mishra                 341
# A Mithun                  34
# A Mukund                  19
# A Nehra                   41
# A Singh                    2
# A Symonds                974
# A Uniyal                   4
# A Zampa                    5
# AA Bilakhia               69
# AA Chavan                 12
# AA Jhunjhunwala          217
# AA Noffke                  9
# AB Agarkar               179
# AB Barath                 42
# AB Dinda                  26
# AB McDonald              123
# AB de Villiers          3974
# AC Blizzard              120
# AC Gilchrist            2069
# AC Thomas                 20
# AC Voges                 181
# AD Mascarenhas            79
#                         ...
# ...

# %%
team_score = d.groupby(['match_id', 'inning'])['total_runs'].sum()
team_score
# Out:
# match_id  inning
# 1         1         207
#           2         172
# 2         1         184
#           2         187
# 3         1         183
#           2         184
# 4         1         163
#           2         164
# 5         1         157
#           2         142
# 6         1         135
#           2         140
# 7         1         178
#           2         180
# 8         1         148
#           2         150
# 9         1         205
#           2         108
# 10        1         158
#           2         159
# 11        1         170
#           2         171
# 12        1         142
#           2         145
# 13        1         171
#           2         172
# 14        1         172
#           2         155
# 15        1         188
#           2         137
#                    ...
# 7939      1         192
#           2         181
# 7940      1         177
#           2         181
# 7941      1          93
#           2          96
# ...

# %%
team_score = d.groupby([ 'inning','batsman'])['total_runs'].sum()
team_score
# Out:
# inning  batsman
# 1       A Ashish Reddy       169
#         A Chandila             4
#         A Chopra              56
#         A Choudhary           15
#         A Dananjaya            4
#         A Flintoff            23
#         A Hales               54
#         A Kumble              16
#         A Mishra             163
#         A Mithun               8
#         A Mukund              20
#         A Nehra               11
#         A Singh                1
#         A Symonds            646
#         A Uniyal               4
#         AA Bilakhia           35
#         AA Chavan              8
#         AA Jhunjhunwala      148
#         AB Agarkar           123
#         AB Dinda               8
#         AB McDonald           81
#         AB de Villiers      2393
#         AC Blizzard           44
#         AC Gilchrist        1025
#         AC Thomas              0
#         AC Voges             147
#         AD Mascarenhas        45
#         AD Mathews           432
# ...

# %%
A=d[d.batsman=='A Ashish Reddy' ]
A
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 81613        346       1      Deccan Chargers               Mumbai Indians
# 81614        346       1      Deccan Chargers               Mumbai Indians
# 81615        346       1      Deccan Chargers               Mumbai Indians
# 81616        346       1      Deccan Chargers               Mumbai Indians
# 81618        346       1      Deccan Chargers               Mumbai Indians
# 81622        346       1      Deccan Chargers               Mumbai Indians
# 81623        346       1      Deccan Chargers               Mumbai Indians
# 81624        346       1      Deccan Chargers               Mumbai Indians
# 81625        346       1      Deccan Chargers               Mumbai Indians
# 81626        346       1      Deccan Chargers               Mumbai Indians
# 83206        352       2      Deccan Chargers          Chennai Super Kings
# ...

# %%
A.total_runs.sum()
# Out:
# 288

# %%
v= d[d.batsman=='V Kohli']
v
# Out:
#         match_id  inning                 batting_team         bowling_team  \
# 2590          12       1  Royal Challengers Bangalore       Mumbai Indians
# 2591          12       1  Royal Challengers Bangalore       Mumbai Indians
# 2593          12       1  Royal Challengers Bangalore       Mumbai Indians
# 2594          12       1  Royal Challengers Bangalore       Mumbai Indians
# 2597          12       1  Royal Challengers Bangalore       Mumbai Indians
# 2598          12       1  Royal Challengers Bangalore       Mumbai Indians
# 2603          12       1  Royal Challengers Bangalore       Mumbai Indians
# 2604          12       1  Royal Challengers Bangalore       Mumbai Indians
# 2605          12       1  Royal Challengers Bangalore       Mumbai Indians
# 2606          12       1  Royal Challengers Bangalore       Mumbai Indians
# 2607          12       1  Royal Challengers Bangalore       Mumbai Indians
# ...

# %%
v.total_runs.sum()
# Out:
# 5136

# %%
v.count(
# Out:
# match_id            3879
# inning              3879
# batting_team        3879
# bowling_team        3879
# over                3879
# ball                3879
# batsman             3879
# non_striker         3879
# bowler              3879
# is_super_over       3879
# wide_runs           3879
# bye_runs            3879
# legbye_runs         3879
# noball_runs         3879
# penalty_runs        3879
# batsman_runs        3879
# extra_runs          3879
# total_runs          3879
# player_dismissed     138
# dismissal_kind       138
# fielder              100
# Unnamed: 21            0
# winner                 0
# dtype: int64

# %%
four=d[d["batsman_runs"] == 4]
four
# Out:
#         match_id  inning                 batting_team  \
# 2              1       1          Sunrisers Hyderabad
# 8              1       1          Sunrisers Hyderabad
# 13             1       1          Sunrisers Hyderabad
# 30             1       1          Sunrisers Hyderabad
# 32             1       1          Sunrisers Hyderabad
# 33             1       1          Sunrisers Hyderabad
# 35             1       1          Sunrisers Hyderabad
# 36             1       1          Sunrisers Hyderabad
# 63             1       1          Sunrisers Hyderabad
# 72             1       1          Sunrisers Hyderabad
# 74             1       1          Sunrisers Hyderabad
# 76             1       1          Sunrisers Hyderabad
# 81             1       1          Sunrisers Hyderabad
# 87             1       1          Sunrisers Hyderabad
# 101            1       1          Sunrisers Hyderabad
# 109            1       1          Sunrisers Hyderabad
# ...

# %%
fours_per_batsman = four.groupby(["match_id", "batsman"])["batsman_runs"].count()
fours_per_batsman
# Out:
# match_id  batsman
# 1         CH Gayle            2
#           DA Warner           2
#           KM Jadhav           4
#           MC Henriques        3
#           Mandeep Singh       5
#           S Dhawan            5
#           SR Watson           1
#           TM Head             3
#           Yuvraj Singh        7
# 2         AM Rahane           6
#           BA Stokes           3
#           HH Pandya           1
#           JC Buttler          3
#           KA Pollard          3
#           MA Agarwal          1
#           MS Dhoni            1
#           N Rana              1
#           PA Patel            4
#           SPD Smith           7
# 3         BB McCullum         4
#           CA Lynn             6
#           G Gambhir          12
#           JJ Roy              3
#           KD Karthik          6
#           SK Raina            7
# 4         AM Rahane           1
#           AR Patel            1
#           BA Stokes           2
# ...

# %%
sixes = d[ d["batsman_runs"] == 6]
sixes_per_batsman = sixes.groupby(["match_id", "inning", "batsman"])["batsman_runs"].count()
sixes_per_batsman
# Out:
# match_id  inning  batsman
# 1         1       BCJ Cutting        2
#                   DA Warner          1
#                   DJ Hooda           1
#                   MC Henriques       2
#                   Yuvraj Singh       3
#           2       A Choudhary        1
#                   CH Gayle           3
#                   KM Jadhav          1
#                   SR Watson          1
#                   STR Binny          1
#                   TS Mills           1
# 2         1       HH Pandya          4
#                   JC Buttler         3
#                   KA Pollard         1
#                   N Rana             2
#                   TG Southee         1
#           2       AM Rahane          3
#                   SPD Smith          3
# 3         1       AJ Finch           2
#                   BB McCullum        2
#                   KD Karthik         2
#           2       CA Lynn            8
# 4         1       AM Rahane          1
# ...

# %%
f=d[d. batsman_runs== 4]
f
# Out:
#         match_id  inning                 batting_team  \
# 2              1       1          Sunrisers Hyderabad
# 8              1       1          Sunrisers Hyderabad
# 13             1       1          Sunrisers Hyderabad
# 30             1       1          Sunrisers Hyderabad
# 32             1       1          Sunrisers Hyderabad
# 33             1       1          Sunrisers Hyderabad
# 35             1       1          Sunrisers Hyderabad
# 36             1       1          Sunrisers Hyderabad
# 63             1       1          Sunrisers Hyderabad
# 72             1       1          Sunrisers Hyderabad
# 74             1       1          Sunrisers Hyderabad
# 76             1       1          Sunrisers Hyderabad
# 81             1       1          Sunrisers Hyderabad
# 87             1       1          Sunrisers Hyderabad
# 101            1       1          Sunrisers Hyderabad
# 109            1       1          Sunrisers Hyderabad
# ...

# %%
fou=f.groupby([ "batsman","batsman_runs"])["total_runs"]
F=fou.sum()
F
# Out:
# batsman            batsman_runs
# A Ashish Reddy     4                 64
# A Chopra           4                 28
# A Choudhary        4                  4
# A Flintoff         4                 20
# A Hales            4                 52
# A Kumble           4                 12
# A Mishra           4                108
# A Mithun           4                 16
# A Mukund           4                  4
# A Nehra            4                 12
# A Symonds          4                296
# A Zampa            4                  4
# AA Bilakhia        4                 20
# AA Chavan          4                  8
# AA Jhunjhunwala    4                 76
# AA Noffke          4                  4
# AB Agarkar         4                 52
# AB Barath          4                 20
# AB Dinda           4                  8
# AB McDonald        4                 36
# AB de Villiers     4               1305
# AC Blizzard        4                 84
# AC Gilchrist       4                961
# ...

# %%
six=d[d. batsman_runs== 6]
six
# Out:
#         match_id  inning                 batting_team  \
# 10             1       1          Sunrisers Hyderabad
# 47             1       1          Sunrisers Hyderabad
# 75             1       1          Sunrisers Hyderabad
# 89             1       1          Sunrisers Hyderabad
# 91             1       1          Sunrisers Hyderabad
# 105            1       1          Sunrisers Hyderabad
# 115            1       1          Sunrisers Hyderabad
# 121            1       1          Sunrisers Hyderabad
# 124            1       1          Sunrisers Hyderabad
# 142            1       2  Royal Challengers Bangalore
# 144            1       2  Royal Challengers Bangalore
# 164            1       2  Royal Challengers Bangalore
# 180            1       2  Royal Challengers Bangalore
# 219            1       2  Royal Challengers Bangalore
# 221            1       2  Royal Challengers Bangalore
# 241            1       2  Royal Challengers Bangalore
# ...

# %%
si=six.groupby([ "batsman","batsman_runs"])["total_runs"]
S=si.sum()
S
# Out:
# batsman            batsman_runs
# A Ashish Reddy     6                 90
# A Choudhary        6                  6
# A Flintoff         6                 12
# A Hales            6                 36
# A Mishra           6                 30
# A Mithun           6                  6
# A Nehra            6                  6
# A Symonds          6                246
# AA Jhunjhunwala    6                 30
# AB Agarkar         6                 30
# AB Barath          6                  6
# AB McDonald        6                 24
# AB de Villiers     6               1131
# AC Blizzard        6                 12
# AC Gilchrist       6                552
# AC Thomas          6                  6
# AC Voges           6                 18
# AD Mascarenhas     6                  6
# AD Mathews         6                174
# AD Russell         6                408
# AJ Finch           6                402
# AJ Tye             6                 24
# AL Menaria         6                109
# ...

# %%
bowler_grp = d.groupby(["match_id", "inning", "bowling_team", "bowler", "over"])
bowlers = bowler_grp["total_runs", "wide_runs", "bye_runs", "legbye_runs", "noball_runs"]
bowlers.sum().reset_index()
# Out:
#        match_id  inning                 bowling_team           bowler  over  \
# 0             1       1  Royal Challengers Bangalore      A Choudhary     2
# 1             1       1  Royal Challengers Bangalore      A Choudhary    10
# 2             1       1  Royal Challengers Bangalore      A Choudhary    13
# 3             1       1  Royal Challengers Bangalore      A Choudhary    18
# 4             1       1  Royal Challengers Bangalore        S Aravind     5
# 5             1       1  Royal Challengers Bangalore        S Aravind    12
# 6             1       1  Royal Challengers Bangalore        S Aravind    15
# 7             1       1  Royal Challengers Bangalore        SR Watson     6
# 8             1       1  Royal Challengers Bangalore        SR Watson    14
# 9             1       1  Royal Challengers Bangalore        SR Watson    20
# 10            1       1  Royal Challengers Bangalore        STR Binny    11
# ...

# %%
ov=d[d.bowler=="Sandeep Sharma"]
ov
# Out:
#         match_id  inning                 batting_team         bowling_team  \
# 713            4       1       Rising Pune Supergiant      Kings XI Punjab
# 714            4       1       Rising Pune Supergiant      Kings XI Punjab
# 715            4       1       Rising Pune Supergiant      Kings XI Punjab
# 716            4       1       Rising Pune Supergiant      Kings XI Punjab
# 717            4       1       Rising Pune Supergiant      Kings XI Punjab
# 718            4       1       Rising Pune Supergiant      Kings XI Punjab
# 725            4       1       Rising Pune Supergiant      Kings XI Punjab
# 726            4       1       Rising Pune Supergiant      Kings XI Punjab
# 727            4       1       Rising Pune Supergiant      Kings XI Punjab
# 728            4       1       Rising Pune Supergiant      Kings XI Punjab
# 729            4       1       Rising Pune Supergiant      Kings XI Punjab
# ...

# %%
r=pd.read_csv('C:\\Users\\VIKAS\\Documents\\ipldata (1)\\matches.csv')#import a csv file for ipl data from computer#
r
# Out:
#        id  season       city       date                        team1  \
# 0       1    2017  Hyderabad   4/5/2017          Sunrisers Hyderabad
# 1       2    2017       Pune   4/6/2017               Mumbai Indians
# 2       3    2017     Rajkot   4/7/2017                Gujarat Lions
# 3       4    2017     Indore   4/8/2017       Rising Pune Supergiant
# 4       5    2017  Bangalore   4/8/2017  Royal Challengers Bangalore
# 5       6    2017  Hyderabad   4/9/2017                Gujarat Lions
# 6       7    2017     Mumbai   4/9/2017        Kolkata Knight Riders
# 7       8    2017     Indore  4/10/2017  Royal Challengers Bangalore
# 8       9    2017       Pune  4/11/2017             Delhi Daredevils
# 9      10    2017     Mumbai  4/12/2017          Sunrisers Hyderabad
# 10     11    2017    Kolkata  4/13/2017              Kings XI Punjab
# 11     12    2017  Bangalore  4/14/2017  Royal Challengers Bangalore
# 12     13    2017     Rajkot  4/14/2017       Rising Pune Supergiant
# ...

# %%
team_score = d.groupby(['match_id', 'inning'])['total_runs'].sum().unstack().reset_index()
team_score
# Out:
# inning  match_id      1      2   3   4
# 0              1  207.0  172.0 NaN NaN
# 1              2  184.0  187.0 NaN NaN
# 2              3  183.0  184.0 NaN NaN
# 3              4  163.0  164.0 NaN NaN
# 4              5  157.0  142.0 NaN NaN
# 5              6  135.0  140.0 NaN NaN
# 6              7  178.0  180.0 NaN NaN
# 7              8  148.0  150.0 NaN NaN
# 8              9  205.0  108.0 NaN NaN
# 9             10  158.0  159.0 NaN NaN
# 10            11  170.0  171.0 NaN NaN
# 11            12  142.0  145.0 NaN NaN
# 12            13  171.0  172.0 NaN NaN
# 13            14  172.0  155.0 NaN NaN
# 14            15  188.0  137.0 NaN NaN
# 15            16  176.0  177.0 NaN NaN
# 16            17  161.0  134.0 NaN NaN
# 17            18  168.0  169.0 NaN NaN
# 18            19  159.0  154.0 NaN NaN
# 19            20  213.0  192.0 NaN NaN
# 20            21  191.0  176.0 NaN NaN
# 21            22  198.0  199.0 NaN NaN
# 22            23  187.0  188.0 NaN NaN
# ...

# %%
team_score.columns = ['match_id', 'Team1_score', 'Team2_score', 'Team1_superover_score', 'Team2_superover_score']
team_score.columns
# Out:
# Index(['match_id', 'Team1_score', 'Team2_score', 'Team1_superover_score',
#        'Team2_superover_score'],
#       dtype='object')

# %%
matches_agg = pd.merge(r, team_score, left_on = 'id', right_on = 'match_id', how = 'outer')
matches_agg
# Out:
#          id  season       city       date                        team1  \
# 0       1.0  2017.0  Hyderabad   4/5/2017          Sunrisers Hyderabad
# 1       2.0  2017.0       Pune   4/6/2017               Mumbai Indians
# 2       3.0  2017.0     Rajkot   4/7/2017                Gujarat Lions
# 3       4.0  2017.0     Indore   4/8/2017       Rising Pune Supergiant
# 4       5.0  2017.0  Bangalore   4/8/2017  Royal Challengers Bangalore
# 5       6.0  2017.0  Hyderabad   4/9/2017                Gujarat Lions
# 6       7.0  2017.0     Mumbai   4/9/2017        Kolkata Knight Riders
# 7       8.0  2017.0     Indore  4/10/2017  Royal Challengers Bangalore
# 8       9.0  2017.0       Pune  4/11/2017             Delhi Daredevils
# 9      10.0  2017.0     Mumbai  4/12/2017          Sunrisers Hyderabad
# 10     11.0  2017.0    Kolkata  4/13/2017              Kings XI Punjab
# 11     12.0  2017.0  Bangalore  4/14/2017  Royal Challengers Bangalore
# ...

# %%
x, y = 2008, 2018
while x < y:
    wins_percity = matches_agg[matches_agg['season'] == x].groupby(['winner', 'city'])['match_id'].count().unstack()
    plot = wins_percity.plot(kind='bar', stacked=True, title="Team wins in different cities\nSeason "+str(x), figsize=(7, 5))
    sns.set_palette("Paired", len(matches_agg['city'].unique()))
    plot.set_xlabel("Teams")
    plot.set_ylabel("No of wins")
    plot.legend(loc='best', prop={'size':8})
    x+=1

# %%
D= d[d.batsman=='DA Warner']
D.sum()
# Out:
# match_id                                                   1085379
# inning                                                        4258
# batting_team     Sunrisers HyderabadSunrisers HyderabadSunriser...
# bowling_team     Royal Challengers BangaloreRoyal Challengers B...
# over                                                         21153
# ball                                                         10188
# batsman          DA WarnerDA WarnerDA WarnerDA WarnerDA WarnerD...
# non_striker      S DhawanS DhawanS DhawanS DhawanS DhawanS Dhaw...
# bowler           TS MillsTS MillsTS MillsTS MillsTS MillsA Chou...
# is_super_over                                                    1
# wide_runs                                                      108
# bye_runs                                                        23
# legbye_runs                                                     52
# noball_runs                                                     16
# ...
